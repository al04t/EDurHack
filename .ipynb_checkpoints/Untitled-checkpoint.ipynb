# %%
import panda as pd

# %%
df = pd.read_csv("Dataset/dirtyData/0010762-251025141854904.csv", sep= "\t", usecols=["countryCode", "stateProvince", "individualCount"], dtype=str)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("Dataset/dirtyData/0010762-251025141854904.csv", sep= "\t", usecols=["countryCode", "stateProvince", "individualCount"], dtype=str)
#
# NameError: name 'pd' is not defined
